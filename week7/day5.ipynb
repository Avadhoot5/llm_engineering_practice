# %% [markdown]
# # Week 7 Days 5
#
# Fine-tune an open-source model to Predict Product Prices
#
# Please see this notebook in Google Colab:
#
# https://colab.research.google.com/drive/1bh2jAixXgCsb1N57WnutNVeeKrWnYoJF|

# %% [markdown]
# ### 4 steps - Theory topics
#
# 1. Forward Pass
# 2. Loss Calculatin (Cross-Entropy Loss)
# 3. Backward Pass
# 4. Optimizer
